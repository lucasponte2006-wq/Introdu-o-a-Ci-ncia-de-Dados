# %% [markdown]
# <a href="https://colab.research.google.com/github/lucasponte2006-wq/Introdu-o-a-Ci-ncia-de-Dados/blob/main/C%C3%B3pia_de_ListaExercicios_1_PythonExpress.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***
# ## **<center>Lista de Exercícios 1 - Python Express</center>**
#
#
# **<center>Introdução a Ciência de Dados</center>**
# ***
#
# <br>
#
# Segue uma lista de exercícios abordando o conteúdo inicial para a programação em Python.
#
# Cada exercício deve ser respondido em uma célula específica.
#
#
# 1) Elabore um código que imprima a mensagem *"Olá terráqueos!!"* na tela.
#
#
# 2) Elabore um código que peça um número e então mostre a mensagem: *"O número informado foi [número]."*
#
#
# 3) Elabore um código que peça dois números e imprima a soma.
#
#
# 4) Elabore um código que peça as 4 notas bimestrais e mostre a média.
#
# 5) Elabore um código que converta metros para centímetros.
#
#
# 6) Elabore um código que peça o raio de um círculo, calcule e mostre sua área.
#
# 7) Elabore um código que calcule a área de um quadrado, em seguida mostre o dobro desta área para o usuário.
#
#
# 8) Elabore um código que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês em uma mensagem amigável.
#
#
# 9) Elabore um código que peça a temperatura em graus Fahrenheit, transforme e mostre a temperatura em graus Celsius.
# ** Onde C = 5 * ((F-32) / 9)**.
#
#
# 10) Elabore um código que peça a temperatura em graus Celsius, transforme e mostre em graus Fahrenheit.
#
#
# 11) Elabore um código que peça 2 números inteiros e um número real. Calcule e mostre:
# * o produto do dobro do primeiro com metade do segundo .
# * a soma do triplo do primeiro com o terceiro.
# * o terceiro elevado ao cubo.
#
# 12) Elabore um código que receba os dados de entrada a altura de uma pessoa, e informe qual seria o peso ideal, usando a seguinte fórmula: (72.7*altura) - 58

# %%
# 1) Elabore um código que imprima a mensagem *"Olá terráqueos!!"* na tela.

print("Olá terráqueos")
# Out:
# Olá terráqueos

# %%
# 2) Elabore um código que peça um número e então mostre a mensagem: "O número informado foi [número]."

i = int(input("Informe um número: "))
print("O número informado foi: ", i)

# %%
# 3) Elabore um código que peça dois números e imprima a soma.
n1 = float(input("Digite o primeiro número: "))
n2 = float(input("Digite o segundo número: "))
print(f"A soma é: {n1 + n2}")
# Out:
# Digite o primeiro número: 32
# Digite o segundo número: 45
# A soma é: 77.0

# %%
# 4)Elabore um código que peça as 4 notas bimestrais e mostre a média.
n1 = float(input("Digite a nota do 1º bimestre: "))
n2 = float(input("Digite a nota do 2º bimestre: "))
n3 = float(input("Digite a nota do 3º bimestre: "))
n4 = float(input("Digite a nota do 4º bimestre: "))
media = (n1 + n2 + n3 + n4) / 4
print(f"Sua média bimestral é: {media:.2f}")

if media <= 5:
  print("Você está reprovado!")
else:
  print("Você está aprovado!")
# Out:
# Digite a nota do 1º bimestre: 3
# Digite a nota do 2º bimestre: 4
# Digite a nota do 3º bimestre: 2
# Digite a nota do 4º bimestre: 7
# Sua média bimestral é: 4.00
# Você está reprovado!

# %%
# 5) Elabore um código que converta metros para centímetros.
metros = float(input("Digite o valor em metros: "))
centimetros = metros * 100
print(f"{metros} metro(s) = {centimetros:.0f} centímetro(s)")
# Out:
# Digite o valor em metros: 30
# 30.0 metro(s) = 3000 centímetro(s)

# %%
# 6) Elabore um código que peça o raio de um círculo, calcule e mostre sua área.
import math
raio = float(input("Digite o raio do círculo: "))
area = math.pi * raio ** 2
print(f"A área do círculo com raio {raio} é: {area:.2f}")
# Out:
# Digite o raio do círculo: 5
# A área do círculo com raio 5.0 é: 78.54

# %%
# 7) Elabore um código que calcule a área de um quadrado, em seguida mostre o dobro desta área para o usuário.
lado = float(input("Digite o lado do quadrado: "))
area = lado ** 2
dobro = area * 2
print(f"Área do quadrado: {area:.2f}")
print(f"Dobro da área: {dobro:.2f}")
# Out:
# Digite o lado do quadrado: 3.5
# Área do quadrado: 12.25
# Dobro da área: 24.50

# %%
# 8) Elabore um código que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês em uma mensagem amigável.
valor_hora = float(input("Quanto você ganha por hora? R$ "))
horas = float(input("Quantas horas você trabalhou no mês? "))
salario = valor_hora * horas
print(f"Seu salário total no mês foi de R$ {salario:.2f}. Bom trabalho!")
# Out:
# Quanto você ganha por hora? R$ 7
# Quantas horas você trabalhou no mês? 220
# Seu salário total no mês foi de R$ 1540.00. Bom trabalho!

# %%
# 9) Elabore um código que peça a temperatura em graus Fahrenheit, transforme e mostre a temperatura em graus Celsius. ** Onde C = 5 * ((F-32) / 9)**.
fahrenheit = float(input("Digite a temperatura em Fahrenheit: "))
celsius = 5 * ((fahrenheit -32) / 9)
print(f'{fahrenheit}°F = {celsius:.2f}°C')
# Out:
# Digite a temperatura em Fahrenheit: 45
# 45.0°F = 7.22°C

# %%
# 10) Elabore um código que peça a temperatura em graus Celsius, transforme e mostre em graus Fahrenheit.
celsius = float(input("Digite a temperatura em Celsius: "))
fahrenheit = (celsius * 9 /5) + 32
print(f'{celsius}°C = {fahrenheit:.2f}°F')
# Out:
# Digite a temperatura em Celsius: 32
# 32.0°C = 89.60°F

# %%
# 11) Elabore um código que peça 2 números inteiros e um número real. Calcule e mostre:
#o produto do dobro do primeiro com metade do segundo .
#a soma do triplo do primeiro com o terceiro.
#o terceiro elevado ao cubo.
n1 = int(input("Digite o primeiro número inteiro: "))
n2 = int(input("Digite o segundo número inteiro: "))
n3 = float(input("Digite o número real: "))

resultado1 = (2 * n1) * (n2 / 2)
resultado2 = (3 * n1) + n3
resultado3 = n3 ** 3

print(f"Produto do dobro do primeiro com metade do segundo: {resultado1}")
print(f"Soma do triplo do primeiro com o terceiro: {resultado2}")
print(f"O terceiro elevado ao cubo: {resultado3}")
# Out:
# Digite o primeiro número inteiro: 24
# Digite o segundo número inteiro: 454
# Digite o número real: 2.5
# Produto do dobro do primeiro com metade do segundo: 10896.0
# Soma do triplo do primeiro com o terceiro: 74.5
# O terceiro elevado ao cubo: 15.625

# %%
# 12) Elabore um código que receba os dados de entrada a altura de uma pessoa, e informe qual seria o peso ideal, usando a seguinte fórmula: (72.7*altura) - 58
altura = float(input("Digite sua altura em metros (ex: 1.75): "))
peso_ideal = (72.7 * altura) - 58
print(f"Para uma altura de {altura}m, o peso ideal é {peso_ideal:.1f} kg.")
# Out:
# Digite sua altura em metros (ex: 1.75): 1.71
# Para uma altura de 1.71m, o peso ideal é 66.3 kg.
